# %%
from chat import loading_vectorstore, rag_chain
from langchain.embeddings import OpenAIEmbeddings
from langchain.chat_models import ChatOpenAI
import os
os.environ['OPENAI_API_KEY'] = "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"

# %%
vectordb = loading_vectorstore(path="/home/richiam/pubmed2pdf",chunk_size=1200,chunk_overlap=150, embedding_function=OpenAIEmbeddings(), directory="/home/richiam/test_chat/PI_Chat/data")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 vectordb = loading_vectorstore(path="/home/richiam/pubmed2pdf",chunk_size=1200,chunk_overlap=150, embedding_function=OpenAIEmbeddings(), directory="/home/richiam/test_chat/PI_Chat/data")
#
# File ~/test_chat/PI_Chat/chat.py:115, in loading_vectorstore(path, chunk_size, chunk_overlap, embedding_function, directory)
#     113 docs = load_papers_pdf(path)
#     114 splits = text_splitter(docs, chunk_size=chunk_size, chunk_overlap=chunk_overlap)
# --> 115 vectordb = vectorstore(documents=splits, embedding_function=embedding_function, directory=directory)
#     116 return vectordb
#
# File ~/test_chat/PI_Chat/chat.py:72, in vectorstore(documents, embedding_function, directory)
#      63 def vectorstore(documents, embedding_function, directory):
# ...

# %%
#Changing the prompt so it does allucianate that Adrian Jinich published everything 
template = """You are an assistant for question-answering tasks.The information in {context} are scientific publications in which Adrian Jinich particpated. Use this information to answer questions about the work, life, and publications of Adrian Jinich. If you do not know the answer, just say that you do not know the answer. If unsure, say that you are not sure if Adrian Jinich participated in the study. Use ten sentences maximum and use technical terms in the answers Context:{context} Question: {question}"""
llm = ChatOpenAI(model_name = "gpt-3.5-turbo", temperature=0)
# Making the RAG

rag_ = rag_chain(template=template, retriever=vectordb.as_retriever(), llm=llm)

# %%
rag_.invoke("Who is Adrian Jinich?")
# Out:
# AIMessage(content='Adrian Jinich is a researcher who participated in scientific publications related to thermodynamics and metabolic reactions. He contributed to the investigation, project administration, software development, and writing of these publications.')

# %%
from openai import OpenAI

client = OpenAI(
  organization='org-ya0ngaSgwKa0ThRBrTvG4LpV',
)
# This was not needed, the organization could be defined from chatopenaIa object

# %%
llm_4 = ChatOpenAI(model_name="gpt-4.5",organization="org-ya0ngaSgwKa0ThRBrTvG4LpV")

rag__ = rag_chain(template=template, retriever=vectordb.as_retriever(), llm=llm_4)

# %%
rag__.invoke("Who is Adrian Jinich?")

# %%
# Tryong the Hallucinations with Chatgpt3 and Chatgpt5

rag_.invoke("In what paper was the structure of the DNA proposed ?")
# Out:
# AIMessage(content="Based on the provided information, there is no mention of Adrian Jinich's participation in any paper proposing the structure of DNA. Therefore, it is not possible to determine the paper in which the structure of DNA was proposed.")

# %%
# The Hallucination went away because of the change of the original prompt

rag__.invoke("In what paper was the structure of the DNA proposed ?")
# Out:
# AIMessage(content="I'm sorry, but the documents provided do not contain information about a paper proposing the structure of DNA.")

# %%
# Evaluating the quality oj creating JSONs

rag_.invoke("For each document in the context create a JSON with the keys: Title, Authors, Journal, doi, Methods,abstract, Results, Conclusions and References. Do not make up or summarize information of any kind, take word by word information of the document to complete the task""")
# Out:
# AIMessage(content='{\n  "Title": "SCIENTIFIC REPORTS",\n  "Authors": "Adrian Jinich",\n  "Journal": "SCIENTIFIC REPORTS",\n  "doi": "10.1038/srep07022",\n  "Methods": "Not mentioned in the provided context",\n  "Abstract": "Not mentioned in the provided context",\n  "Results": "Not mentioned in the provided context",\n  "Conclusions": "Not mentioned in the provided context",\n  "References": "Not mentioned in the provided context"\n}\n\n{\n  "Title": "ARTICLE NATURE COMMUNICATIONS",\n  "Authors": "Adrian Jinich",\n  "Journal": "NATURE COMMUNICATIONS",\n  "doi": "https://doi.org/10.1038/s41467-021-26941-1",\n  "Methods": "Not mentioned in the provided context",\n  "Abstract": "Not mentioned in the provided context",\n  "Results": "Not mentioned in the provided context",\n  "Conclusions": "Not mentioned in the provided context",\n  "References": "Not mentioned in the provided context"\n}')

# %%
rag__.invoke("For each document in the {context} create a JSON with the keys: Title, Authors, Journal, doi, Methods,abstract, Results, Conclusions and References. Do not make up or summarize information of any kind, take word by word information of the document to complete the task""")
# Out:
# AIMessage(content="I'm sorry, but the provided content does not include specific information such as Title, Authors, Journal, doi, Methods, Abstract, Results, Conclusions, and References for each document. Therefore, it's impossible to create a JSON file for each document with this specific information without making assumptions or summarizations.")

# %%
# Making a test with the prompt to include the name of the researcher

from chat import loading_vectorstore, rag_chain
from langchain.embeddings import OpenAIEmbeddings
from langchain.chat_models import ChatOpenAI
import os
from langchain.vectorstores import Chroma

os.environ['OPENAI_API_KEY'] = "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"

# %%
name = "Adrian Jinich"
def get_name():
    return "Adrian Jinich"
test_name = "test"
vectordb = Chroma(persist_directory="/home/richiam/test_chat/PI_Chat/data", embedding_function=OpenAIEmbeddings())
template = """You are an assistant for question-answering tasks.The information in {context} are scientific publications in which {name} particpated. Use this information to answer questions about the work, life, and publications of {name}. If you do not know the answer, just say that you do not know the answer. If unsure, say that you are not sure. Use ten sentences maximum and use technical terms in the answers Context:{context}"""
llm = ChatOpenAI(model_name = "gpt-3.5-turbo", temperature=0)
# Making the RAG

# rag_test = rag_chain(template=template,name_func=get_name,retriever=vectordb.as_retriever(), llm=llm)

# %%
rag_test.invoke("Who is Adrian Jinich?")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 rag_test.invoke("Who is Adrian Jinich?")
#
# File ~/anaconda3/envs/langchain/lib/python3.11/site-packages/langchain/schema/runnable/base.py:1426, in RunnableSequence.invoke(self, input, config)
#    1424 try:
#    1425     for i, step in enumerate(self.steps):
# -> 1426         input = step.invoke(
#    1427             input,
#    1428             # mark each step as a child run
#    1429             patch_config(
#    1430                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    1431             ),
#    1432         )
#    1433 # finish the root run
#    1434 except BaseException as e:
#
# File ~/anaconda3/envs/langchain/lib/python3.11/site-packages/langchain/schema/runnable/base.py:1937, in RunnableParallel.invoke(self, input, config)
# ...

# %%
from langchain.schema.runnable import RunnablePassthrough
from langchain.prompts import PromptTemplate
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
import os
from langchain.chat_models import ChatOpenAI
os.environ['OPENAI_API_KEY'] = "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"

llm = ChatOpenAI(model_name = "gpt-3.5-turbo",organization="org-ya0ngaSgwKa0ThRBrTvG4LpV",temperature=0)


def get_name(_):
    return "Adrian Jinich"
vectordb = Chroma(persist_directory="/home/richiam/test_chat/PI_Chat/data", embedding_function=OpenAIEmbeddings())
template = """You are an assistant for question-answering tasks.The information in {context} are scientific publications in which {name} particpated. Use this information to answer questions about the work, life, and publications of {name}. If you do not know the answer, just say that you do not know the answer. If unsure, say that you are not sure. Use ten sentences maximum and use technical terms in the answers Context:{context}"""
name_runnable = RunnablePassthrough(get_name)
rag_prompt_custom = PromptTemplate(input_variables=["name","context","question"],template=template)
rag_ = ({"name":name_runnable, "context": vectordb.as_retriever(), "question": RunnablePassthrough()} | rag_prompt_custom | llm)

# %%
rag_.invoke("Who is Adrian Jinich?")
# Out:
# AIMessage(content='Adrian Jinich is a researcher who participated in the investigation, project administration, software development, supervision, visualization, and writing of scientific publications. He contributed to the original draft and the review/editing process of the papers. Adrian Jinich collaborated with other researchers such as Haniu Ren, Sung-Jin Kim, Elad Noor, Avi Flamholz, Benjamin Sanchez-Lengeling, Charles A.R. Cotton, and Ala´n Aspuru-Guzik. The publications he worked on focused on topics related to thermodynamic constraints, carbon fixation pathways, and redox biochemistry. Some of the papers he contributed to were published in the journal Biochim Biophys Acta and PLOS Computational Biology.')

# %%
vectordb._collection.get(include=['embeddings'])['embeddings'][0]
# Out:
# [-0.0015573427081108093,
#  -0.008573303930461407,
#  0.002741627162322402,
#  -0.03037962131202221,
#  -0.02004660852253437,
#  -0.007799031678587198,
#  -0.0021697215270251036,
#  0.023397093638777733,
#  -0.02593107521533966,
#  -0.021060200408101082,
#  0.0107201486825943,
#  0.018934471532702446,
#  0.01573883928358555,
#  0.007890536449849606,
#  -0.02214418165385723,
#  -0.008925245143473148,
#  0.03282913565635681,
#  -0.023340784013271332,
#  -0.0010496665490791202,
#  0.0030337388161569834,
#  -0.015527674928307533,
#  0.01230388693511486,
#  0.0033751223236322403,
#  -0.023383017629384995,
#  -0.003720025299116969,
#  0.042233023792505264,
#  0.012219421565532684,
#  -0.02947865054011345,
#  0.0043042488396167755,
#  -0.0007324789767153561,
#  0.005247453227639198,
#  -0.008193206042051315,
#  -0.012557285837829113,
#  -0.005606433842331171,
#  -0.025719910860061646,
#  -0.03392719477415085,
#  -0.0039558266289532185,
#  0.0052650501020252705,
#  0.029816513881087303,
# ...

# %%
from chat import loading_vectorstore, rag_chain
from langchain.embeddings import OpenAIEmbeddings
from langchain.chat_models import ChatOpenAI
import os
from langchain.vectorstores import Chroma

os.environ['OPENAI_API_KEY'] = "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"

# %%
rag_test.invoke("Who is Adrian Jinich?")
# Out:
# AIMessage(content='Adrian Jinich is a participant in the scientific publication titled "Cell Lineage Analysis of the Mammalian Female Germline" by Reizel et al. in 2012. This publication focuses on the analysis of the cell lineage in the female germline. Adrian Jinich\'s contribution to this research is not specified in the provided information. The publication was published in the journal PLoS Genetics, volume 8, issue 2, with the article number e1002477. The publication received funding from the Converging Technologies Program of the Israel Science Foundation and the European Union FP7-ERC-AdG, as well as the Yeda-Sela Center for Basic Research. The funders did not have a role in the study design, data collection and analysis, decision to publish, or preparation of the manuscript. A patent on the cell lineage analysis method used in this manuscript has been filed by Yeda Ltd, the licensing arm of the Weizmann Institute.')

# %%
from chat_implementation import pi_chat
import os
os.environ['OPENAI_API_KEY'] = "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"

# %%
rag = pi_chat(name="Adrian Jinich", email="richiam@uchicago.edu",number_papers=20,model_name="gpt-3.5-turbo",path_pubmed="/home/richiam/pubmed2pdf",path_directory="/home/richiam/test_chat/PI_Chat/som")
# Out:
# ...
# 2023-12-05 02:01:31,350 - INFO - pubmed2pdf.cli - Trying to fetch pmid 37405387
# 2023-12-05 02:01:34,639 - INFO - pubmed2pdf.cli - Trying to fetch pmid 36945430
# 2023-12-05 02:01:34,639 - INFO - pubmed2pdf.cli - Trying to fetch pmid 36802628
# 2023-12-05 02:01:35,295 - INFO - pubmed2pdf.cli - Trying to fetch pmid 36247217
# 2023-12-05 02:01:37,412 - INFO - pubmed2pdf.cli - Trying to fetch pmid 35337802
# 2023-12-05 02:01:38,360 - INFO - pubmed2pdf.cli - Trying to fetch pmid 34782606
# 2023-12-05 02:01:38,360 - INFO - pubmed2pdf.cli - Trying to fetch pmid 33376214
# 2023-12-05 02:01:38,653 - INFO - pubmed2pdf.cli - Trying to fetch pmid 33068537
# 2023-12-05 02:01:39,658 - INFO - pubmed2pdf.cli - Trying to fetch pmid 31733221
# 2023-12-05 02:01:42,122 - INFO - pubmed2pdf.cli - Trying to fetch pmid 31404220
# 2023-12-05 02:01:42,625 - INFO - pubmed2pdf.cli - Trying to fetch pmid 30898926
# 2023-12-05 02:01:43,617 - INFO - pubmed2pdf.cli - Trying to fetch pmid 30356318
# ...

# %%
rag.invoke("Who is Adrian Jinich?")
# Out:
# AIMessage(content='Adrian Jinich is a researcher who has participated in scientific investigations and projects. He has contributed to the project administration, software development, and writing of scientific papers. He has also been involved in the supervision and visualization aspects of the projects. Adrian Jinich has collaborated with other researchers such as Haniu Ren, Sung-Jin Kim, Elad Noor, Benjamin Sanchez-Lengeling, Avi Flamholz, Charles A.R. Cotton, and Ala´n Aspuru-Guzik. Some of the publications he has been involved in include "Thermodynamic constraints shape the structure of carbon fixation pathways" and "Does acetogenesis really require especially low reduction potential?". Adrian Jinich\'s contributions have focused on the thermodynamics of metabolic reactions and the use of quantum chemical approaches to estimate them.')
